# %% [markdown]
# # Pre-Entrega Gabriela Vignolo
# ## Importacion de librerias

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ## Lectura del dataset y utilizacion del metodo head

# %%
df = pd.read_csv('Students_Dataset.csv')
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
# 3                           1                       1            1
# 4                           0                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# ...

# %% [markdown]
# ## Eliminacion de columnas que no se utilizaran

# %%
columnas_a_eliminar = ['Application mode', 'Application order','Previous qualification','Curricular units 1st sem (credited)','Curricular units 1st sem (enrolled)','Curricular units 1st sem (evaluations)','Curricular units 1st sem (evaluations)','Curricular units 1st sem (approved)','Curricular units 1st sem (grade)','Curricular units 1st sem (without evaluations)','Curricular units 2nd sem (credited)','Curricular units 2nd sem (enrolled)','Curricular units 2nd sem (evaluations)','Curricular units 2nd sem (evaluations)','Curricular units 2nd sem (approved)','Curricular units 2nd sem (grade)','Curricular units 2nd sem (without evaluations)','Educational special needs','Debtor','Tuition fees up to date','International','Scholarship holder','Unemployment rate','Inflation rate','GDP','Displaced']
df = df.drop(columns=columnas_a_eliminar)

# %% [markdown]
# ## Utilizacion del metodo head y describe del datadrame limpio

# %%
df.head()
# Out:
#    Marital status  Course  Daytime/evening attendance  Nacionality  \
# 0               1       2                           1            1
# 1               1      11                           1            1
# 2               1       5                           1            1
# 3               1      15                           1            1
# 4               2       3                           0            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  \
# 0                      13                      10                    6
# 1                       1                       3                    4
# 2                      22                      27                   10
# 3                      23                      27                    6
# 4                      22                      28                   10
#
#    Father's occupation  Gender  Age at enrollment    Target
# 0                   10       1                 20   Dropout
# ...

# %%
df.describe().round(2) #Metodo round para rendondar a 2 decimales
# Out:
#        Marital status   Course  Daytime/evening attendance  Nacionality  \
# count         4424.00  4424.00                     4424.00      4424.00
# mean             1.18     9.90                        0.89         1.25
# std              0.61     4.33                        0.31         1.75
# min              1.00     1.00                        0.00         1.00
# 25%              1.00     6.00                        1.00         1.00
# 50%              1.00    10.00                        1.00         1.00
# 75%              1.00    13.00                        1.00         1.00
# max              6.00    17.00                        1.00        21.00
#
#        Mother's qualification  Father's qualification  Mother's occupation  \
# count                 4424.00                 4424.00              4424.00
# mean                    12.32                   16.46                 7.32
# std                      9.03                   11.04                 4.00
# ...

# %% [markdown]
# #### De esta descripcion se obtienen los siguientes datos:
# - Marital status: La mayoria de los alumnos son solteros (1=Sorltero)
# - VER Course: Promedio de 9.90, lo que sugiere que el curso elegido en promedio está en el rango alto de 1 a 17.
# - VER Daytime/evening attendance: Promedio de 0.89, indicando que la mayoría de los registros tienen asistencia durante el día/noche.
# - VER Nacionality: Promedio de 1.25 indica que los valores de nacionalidad están centrados en 1 (Portugues).
# - VER Mother's qualification y Father's qualification: Promedios indican los niveles de calificación en promedio.
# - VER Mother's occupation y Father's occupation: Promedios sugieren el rango de ocupaciones.
# - ver Gender: Promedio de 0.35, 35% son de sexo masculino y 75% de sexo femenino.
# - Age at enrollment: El promedio de edad es de 23.27 años. Con un minimo de 17 y un maximo de 70 años.

# %% [markdown]
# ## Graficos

# %% [markdown]
# ### Heatmap
#
# Veremos por medio de este grafico qué variables tienen influencia en el éxito académico y lograr asi interpretar cómo diferentes factores afectan la probabilidad de graduación o abandono.

# %%
# Codificar la columna 'Target' a valores numéricos
df['Target'] = df['Target'].map({'Graduate': 1, 'Dropout': 0})

# Mostrar la correlación de cada variable con 'Target'
corr_with_target = corr_matrix['Target'].sort_values(ascending=False)
print(corr_with_target)

# Realizacion del grafico
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1, linewidths=0.5)
plt.title('Matriz de Correlación')
plt.show()
# Out:
# Target                        1.000000
# Daytime/evening attendance    0.084496
# Father's occupation           0.073238
# Mother's occupation           0.064195
# Course                        0.006814
# Nacionality                  -0.003823
# Father's qualification       -0.003850
# Mother's qualification       -0.048459
# Marital status               -0.100479
# Gender                       -0.251955
# Age at enrollment            -0.267229
# Name: Target, dtype: float64

# %% [markdown]
# ### Analisis del heatmap: Correlacion con la variable Target:
#
# #### Interpretación del Heatmap:
#
# Colores: En el heatmap, los colores representan la fuerza y la dirección de la correlación. Las correlaciones positivas son representadas con colores cálidos (como el rojo), mientras que las correlaciones negativas se muestran con colores fríos (como el azul). La intensidad del color indica la fuerza de la correlación.
#
# Valores: Los valores numéricos en el heatmap te permiten ver la fuerza exacta de la correlación. Los valores cercanos a 1 o -1 indican una correlación fuerte, mientras que los valores cercanos a 0 indican una correlación débil o nula.
#
# - Target: La diagonal principal muestra la correlación de Target consigo misma, que es siempre 1.0.
# - Daytime/evening attendance (0.084): Correlación positiva  débil, relación muy ligera entre la asistencia durante el día/noche y la probabilidad de ser Graduate o Dropout.
# - Father's occupation (0.073) y Mother's occupation (0.064): Correlación positiva muy débil con Target, sugiriendo que la ocupación de los padres tiene poca influencia en la probabilidad de ser Graduate o Dropout.
# - Course (0.007): La correlación es cercana a cero, indicando prácticamente ninguna relación con Target.
# - Nacionality (-0.004): La correlación es muy cercana a cero, por lo que la nacionalidad no tiene una relación significativa con Target.
# - Father's qualification (-0.004) y Mother's qualification (-0.048): También tienen una correlación muy débil y negativa con Target.
# - Marital status (-0.100): Tiene una correlación negativa debil con Target.
# - Gender (-0.252): Hay una correlación negativa moderada, indicando que el género tiene una influencia más notable en la probabilidad de ser Graduate o Dropout.
# - Age at enrollment (-0.267): La correlación negativa con Target es relativamente fuerte, sugiriendo que la edad en la inscripción tiene una influencia considerable en el éxito académico.
#
# #### Conclusiones preliminares:
#
# Las variables como Gender y Age at enrollment tienen correlaciones más significativas con Target, lo que podría sugerir que el género y la edad al momento de la inscripción son factores más relevantes en el éxito académico o la probabilidad de abandono.
# Variables como Daytime/evening attendance, Father's occupation, y Mother's occupation tienen una correlación muy baja con Target, lo que indica que tienen poco impacto en el Target.

# %% [markdown]
# ### Grafico de distribucion por genero

# %%
# Realizacion de countplot
sns.countplot(x='Gender', data=df,  hue='Gender', width=0.4, palette={0: '#FF69B4', 1: '#87CEEB'})
plt.title('Distribución de Género')
plt.xlabel('Género')
plt.ylabel('Cantidad')
plt.xticks(ticks=[0, 1], labels=['Femenino', 'Masculino']) 
plt.show()

# %% [markdown]
# ### Grafico utilizando hue para dividir los datos por género

# %%
# Contar las ocurrencias de cada edad
age_counts = df['Age at enrollment'].value_counts()

# Seleccionar las 20 edades más comunes
top_20_ages = age_counts.head(20)

# Crear una lista con las 20 edades más comunes
top_20_ages_list = top_20_ages.index

# Filtrar el DataFrame para incluir solo las filas con esas 20 edades
filtered_students = df[df['Age at enrollment'].isin(top_20_ages_list)]

# Graficar
sns.countplot(x='Age at enrollment', data=filtered_students, hue='Gender', palette={0: '#FF69B4', 1: '#87CEEB'})

plt.title('Distribución de Edades por Género (Top 20)')
plt.xlabel('Edades')
plt.ylabel('Cantidad')
plt.show()

# %% [markdown]
# ### Grafico de Edad promedio de inscripcion por genero:

# %%
sns.barplot(x='Gender', y='Age at enrollment', data=df, hue='Gender', width=0.4, palette={0: '#FF69B4', 1: '#87CEEB'})
plt.title('Edad Promedio de Inscripción por Género')
plt.xlabel('Genero')
plt.ylabel('Edad Promedio de Inscripción')
plt.xticks(ticks=[0, 1], labels=['Femenino', 'Masculino'])
plt.show()

# %% [markdown]
# ### Boxplot
#
# Realizacion de Boxplot para analisis de outliers.

# %%
# Realizacion del grafico: 'Age at enrollment' según 'Gender'
plt.figure(figsize=(8, 6))
sns.boxplot(x='Gender', y='Age at enrollment', data=df, hue='Gender', width=0.4, palette={0: '#FF69B4', 1: '#87CEEB'})
plt.title('Distribución de Edad al Inscribirse por Género')
plt.xlabel('Género')
plt.ylabel('Edad al Inscribirse')
plt.xticks(ticks=[0, 1], labels=['Femenino', 'Masculino'])
plt.show()

# %% [markdown]
# ### Calcular mediana de edad por genero:

# %%
# df = pd.read_csv('ruta/a/tu/archivo.csv')  # Si es necesario cargar el DataFrame

# Calcular la mediana de 'Age at enrollment' para cada género
mediana_edad_femenino = df[df['Gender'] == 0]['Age at enrollment'].median()
mediana_edad_masculino = df[df['Gender'] == 1]['Age at enrollment'].median()

print(f"Mediana de Edad al Inscribirse (Femenino): {mediana_edad_femenino}")
print(f"Mediana de Edad al Inscribirse (Masculino): {mediana_edad_masculino}")
# Out:
# Mediana de Edad al Inscribirse (Femenino): 19.0
# Mediana de Edad al Inscribirse (Masculino): 21.0

# %%
def calcular_outliers(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    limites_inferiores = Q1 - 1.5 * IQR
    limites_superiores = Q3 + 1.5 * IQR
    return data[(data < limites_inferiores) | (data > limites_superiores)]

# Calcular outliers para cada género
outliers_femenino = calcular_outliers(df[df['Gender'] == 0]['Age at enrollment'])
outliers_masculino = calcular_outliers(df[df['Gender'] == 1]['Age at enrollment'])

print("Valores atípicos para mujeres:")
print(outliers_femenino)
print("\nValores atípicos para hombres:")
print(outliers_masculino)
# Out:
# Valores atípicos para mujeres:
# 4       45
# 37      55
# 38      39
# 56      39
# 84      33
#         ..
# 4357    31
# 4378    32
# 4388    42
# 4391    32
# 4415    46
# Name: Age at enrollment, Length: 356, dtype: int64
#
# Valores atípicos para hombres:
# 5       50
# 36      43
# 678     50
# 684     49
# 685     46
#         ..
# 3728    42
# 3850    47
# 3851    55
# 3859    42
# 4408    47
# Name: Age at enrollment, Length: 101, dtype: int64
